# %%
# Importing necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
# Loading the dataset
suicidal= pd.read_csv("Suicides in India.csv")

# %%
suicidal
# Out:
#                 State  Year      Type_code  \
# 0       A & N Islands  2001         Causes
# 1       A & N Islands  2001         Causes
# 2       A & N Islands  2001         Causes
# 3       A & N Islands  2001         Causes
# 4       A & N Islands  2001         Causes
# ...               ...   ...            ...
# 237514    West Bengal  2012  Social_Status
# 237515    West Bengal  2012  Social_Status
# 237516    West Bengal  2012  Social_Status
# 237517    West Bengal  2012  Social_Status
# 237518    West Bengal  2012  Social_Status
#
#                                            Type  Gender Age_group  Total
# 0                            Illness (Aids/STD)  Female      0-14      0
# 1       Bankruptcy or Sudden change in Economic  Female      0-14      0
# 2       Cancellation/Non-Settlement of Marriage  Female      0-14      0
# 3             Physical Abuse (Rape/Incest Etc.)  Female      0-14      0
# 4                                 Dowry Dispute  Female      0-14      0
# ...

# %%
suicidal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237519 entries, 0 to 237518
# Data columns (total 7 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   State      237519 non-null  object
#  1   Year       237519 non-null  int64
#  2   Type_code  237519 non-null  object
#  3   Type       237519 non-null  object
#  4   Gender     237519 non-null  object
#  5   Age_group  237519 non-null  object
#  6   Total      237519 non-null  int64
# dtypes: int64(2), object(5)
# memory usage: 12.7+ MB

# %%
suicidal.Type_code.value_counts()
# Out:
# Causes                  109200
# Means_adopted            67200
# Professional_Profile     49263
# Education_Status          7296
# Social_Status             4560
# Name: Type_code, dtype: int64

# %%
suicidal.Age_group.value_counts()
# Out:
# 15-29     45223
# 30-44     45193
# 45-59     45146
# 60+       45074
# 0-14      45027
# 0-100+    11856
# Name: Age_group, dtype: int64

# %%
suicidal.Type.value_counts()
# Out:
# Others (Please Specify)                           7263
# Other Causes (Please Specity)                     4200
# Causes Not known                                  4200
# Illegitimate Pregnancy                            4200
# Fall in Social Reputation                         4200
#                                                   ...
# Diploma                                            912
# Graduate                                           912
# Not having Children (Barrenness/Impotency          350
# By Other means                                     350
# Bankruptcy or Sudden change in Economic Status     350
# Name: Type, Length: 69, dtype: int64

# %% [markdown]
# # Data Cleaning

# %%
# Checking null values in the Dataset
suicidal.isnull().any()
# Out:
# State        False
# Year         False
# Type_code    False
# Type         False
# Gender       False
# Age_group    False
# Total        False
# dtype: bool

# %%
suicidal.State.unique()
# Out:
# array(['A & N Islands', 'Andhra Pradesh', 'Arunachal Pradesh', 'Assam',
#        'Bihar', 'Chandigarh', 'Chhattisgarh', 'D & N Haveli',
#        'Daman & Diu', 'Delhi (Ut)', 'Goa', 'Gujarat', 'Haryana',
#        'Himachal Pradesh', 'Jammu & Kashmir', 'Jharkhand', 'Karnataka',
#        'Kerala', 'Lakshadweep', 'Madhya Pradesh', 'Maharashtra',
#        'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha',
#        'Puducherry', 'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu',
#        'Total (All India)', 'Total (States)', 'Total (Uts)', 'Tripura',
#        'Uttar Pradesh', 'Uttarakhand', 'West Bengal'], dtype=object)

# %%
# Dropping the rows in State having Value Total(All India,States and Uts)
suicidal.drop(suicidal[suicidal['State']=='Total (All India)'].index,inplace = True)
suicidal.drop(suicidal[suicidal['State']=='Total (States)'].index,inplace = True)
suicidal.drop(suicidal[suicidal['State']=='Total (Uts)'].index,inplace = True)
suicidal.drop(suicidal[suicidal['Total']==0].index,inplace = True)
suicidal
# Out:
#                 State  Year      Type_code                           Type  \
# 13      A & N Islands  2001         Causes                   Love Affairs
# 20      A & N Islands  2001         Causes  Other Causes (Please Specity)
# 32      A & N Islands  2001         Causes        Other Prolonged Illness
# 47      A & N Islands  2001         Causes         Failure in Examination
# 54      A & N Islands  2001         Causes        Other Prolonged Illness
# ...               ...   ...            ...                            ...
# 237514    West Bengal  2012  Social_Status                      Seperated
# 237515    West Bengal  2012  Social_Status                Widowed/Widower
# 237516    West Bengal  2012  Social_Status                        Married
# 237517    West Bengal  2012  Social_Status                       Divorcee
# 237518    West Bengal  2012  Social_Status                  Never Married
#
#         Gender Age_group  Total
# 13      Female      0-14      1
# ...

# %%
suicidal.State.unique()
# Out:
# array(['A & N Islands', 'Andhra Pradesh', 'Arunachal Pradesh', 'Assam',
#        'Bihar', 'Chandigarh', 'Chhattisgarh', 'D & N Haveli',
#        'Daman & Diu', 'Delhi (Ut)', 'Goa', 'Gujarat', 'Haryana',
#        'Himachal Pradesh', 'Jammu & Kashmir', 'Jharkhand', 'Karnataka',
#        'Kerala', 'Lakshadweep', 'Madhya Pradesh', 'Maharashtra',
#        'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha',
#        'Puducherry', 'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu',
#        'Tripura', 'Uttar Pradesh', 'Uttarakhand', 'West Bengal'],
#       dtype=object)

# %%
# Renaming State
suicidal['State']=suicidal['State'].replace({'Delhi (Ut)':'Delhi'})

# %%
suicidal.State.unique()
# Out:
# array(['A & N Islands', 'Andhra Pradesh', 'Arunachal Pradesh', 'Assam',
#        'Bihar', 'Chandigarh', 'Chhattisgarh', 'D & N Haveli',
#        'Daman & Diu', 'Delhi', 'Goa', 'Gujarat', 'Haryana',
#        'Himachal Pradesh', 'Jammu & Kashmir', 'Jharkhand', 'Karnataka',
#        'Kerala', 'Lakshadweep', 'Madhya Pradesh', 'Maharashtra',
#        'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha',
#        'Puducherry', 'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu',
#        'Tripura', 'Uttar Pradesh', 'Uttarakhand', 'West Bengal'],
#       dtype=object)

# %%
suicidal.Age_group.unique()
# Out:
# array(['0-14', '15-29', '30-44', '45-59', '60+', '0-100+'], dtype=object)

# %%
suicidal.Type_code.unique()
# Out:
# array(['Causes', 'Education_Status', 'Means_adopted',
#        'Professional_Profile', 'Social_Status'], dtype=object)

# %%
suicidal.Type.unique()
# Out:
# array(['Love Affairs', 'Other Causes (Please Specity)',
#        'Other Prolonged Illness', 'Failure in Examination',
#        'Causes Not known', 'Family Problems', 'Insanity/Mental Illness',
#        'Death of Dear Person', 'No Education', 'Middle', 'Primary',
#        'Matriculate/Secondary', 'Graduate',
#        'Hr. Secondary/Intermediate/Pre-Universit', 'By Hanging',
#        'By Fire/Self Immolation', 'By Consuming Other Poison',
#        'By Drowning', 'Student', 'Others (Please Specify)', 'House Wife',
#        'Service (Private)', 'Public Sector Undertaking',
#        'Service (Government)', 'Farming/Agriculture Activity',
#        'Retired Person', 'Married', 'Never Married', 'Unemployment',
#        'Post Graduate and Above', 'Self-employed (Business activity)',
#        'Fall in Social Reputation', 'Suspected/Illicit Relation',
#        'Cancellation/Non-Settlement of Marriage',
#        'Not having Children(Barrenness/Impotency', 'Poverty',
# ...

# %%
len(suicidal.Type.unique())
# Out:
# 69

# %%
# Renaming Type
suicidal['Type'].replace({"By Jumping from (Other sites)":"By Jumping", 
        "By Jumping off Moving Vehicles/Trains":"By Jumping", 
        "By Jumping from (Building)":"By Jumping",
        "Bankruptcy or Sudden change in Economic Status":"Bankruptcy or Sudden change in Economic",
        "Not having Children (Barrenness/Impotency":"Not having Children(Impotency)"},inplace=True)

# %%
suicidal.Type.unique()
# Out:
# array(['Love Affairs', 'Other Causes (Please Specity)',
#        'Other Prolonged Illness', 'Failure in Examination',
#        'Causes Not known', 'Family Problems', 'Insanity/Mental Illness',
#        'Death of Dear Person', 'No Education', 'Middle', 'Primary',
#        'Matriculate/Secondary', 'Graduate',
#        'Hr. Secondary/Intermediate/Pre-Universit', 'By Hanging',
#        'By Fire/Self Immolation', 'By Consuming Other Poison',
#        'By Drowning', 'Student', 'Others (Please Specify)', 'House Wife',
#        'Service (Private)', 'Public Sector Undertaking',
#        'Service (Government)', 'Farming/Agriculture Activity',
#        'Retired Person', 'Married', 'Never Married', 'Unemployment',
#        'Post Graduate and Above', 'Self-employed (Business activity)',
#        'Fall in Social Reputation', 'Suspected/Illicit Relation',
#        'Cancellation/Non-Settlement of Marriage',
#        'Not having Children(Barrenness/Impotency', 'Poverty',
# ...

# %%
len(suicidal.Type.unique())
# Out:
# 66

# %%
suicidal.head(4)
# Out:
#             State  Year Type_code                           Type  Gender  \
# 13  A & N Islands  2001    Causes                   Love Affairs  Female
# 20  A & N Islands  2001    Causes  Other Causes (Please Specity)  Female
# 32  A & N Islands  2001    Causes        Other Prolonged Illness    Male
# 47  A & N Islands  2001    Causes         Failure in Examination    Male
#
#    Age_group  Total
# 13      0-14      1
# 20      0-14      1
# 32      0-14      1
# 47      0-14      1

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ### Suicide Rate (By Year)

# %%
df1=suicidal.groupby(['Year','Gender'])['Total'].sum().reset_index().sort_values('Total',ascending=False)
plt.figure(figsize=(10,6))
sb.barplot(x='Year',y='Total',hue='Gender',data=df1,ci=False,palette='seismic')

# %% [markdown]
# The total number of suicides are been increasing fromm 2001 to 2011 but after this there's a slight decrease in suicide rate.

# %% [markdown]
# ### Gender Suicide Frequency

# %%
sb.barplot(x='Gender',y='Total',data=suicidal,ci=False)

# %% [markdown]
# ### State having maximum number of Suicides.

# %%
df2=suicidal.groupby(['State','Gender'])['Total'].sum().reset_index().sort_values('Total',ascending=False)
plt.figure(figsize=(12,8))
plt.xticks(rotation=90)
sb.set_style('darkgrid')
sb.barplot(x='State',y='Total',hue='Gender',data=df2,ci=False,palette='magma_r')

# %% [markdown]
# Maharastra records maximum cases of Suicides in Males whereas West Bengal has highest Female suicide rate.

# %% [markdown]
# ### Which Age group has committed maximum suicides.

# %%
limit = suicidal[~(suicidal['Age_group']=='0-100+')]

# %%
limit.head()
# Out:
#             State  Year Type_code                           Type  Gender  \
# 13  A & N Islands  2001    Causes                   Love Affairs  Female
# 20  A & N Islands  2001    Causes  Other Causes (Please Specity)  Female
# 32  A & N Islands  2001    Causes        Other Prolonged Illness    Male
# 47  A & N Islands  2001    Causes         Failure in Examination    Male
# 54  A & N Islands  2001    Causes        Other Prolonged Illness  Female
#
#    Age_group  Total
# 13      0-14      1
# 20      0-14      1
# 32      0-14      1
# 47      0-14      1
# 54     15-29      8

# %%
limit.groupby(by='Age_group')['Total'].sum().sort_values(ascending=False)
# Out:
# Age_group
# 15-29    1534037
# 30-44    1471599
# 45-59     885177
# 60+       346925
# 0-14       98410
# Name: Total, dtype: int64

# %%
plt.figure(figsize=(10,5))
plt.xticks(rotation=90)
sb.set_style('darkgrid')
sb.barplot(x='Age_group',y='Total',data=limit,ci=False,palette='Dark2')

# %% [markdown]
# From this we conclude that the Age group between 15-44 has highest suicide frequency, i.e., The Middle Age group.
# It's quite surprising that kids from 0-14 has a suicide rate which is scary.

# %% [markdown]
# ### Which is the major cause of attempting suicides.

# %%
plt.figure(figsize=(10,5))
plt.xticks(rotation=90)
sb.barplot(x='Type_code',y='Total',data=suicidal,ci=False,palette='Reds')

# %% [markdown]
# Social Status is the biggest cause of attempting suicides.

# %% [markdown]
# ## Analysis of Suicide causing factors

# %%
# Extracting columns of each type
cause_df=suicidal[suicidal['Type_code']=='Causes']
means_df=suicidal[suicidal['Type_code']=='Means_adopted']
prof_df=suicidal[suicidal['Type_code']=='Professional_Profile']
social_df=suicidal[suicidal['Type_code']=='Social_Status']
edu_df=suicidal[suicidal['Type_code']=='Education_Status']

# %% [markdown]
# #### Due to Causes

# %%
cause_df.head(4)
# Out:
#             State  Year Type_code                           Type  Gender  \
# 13  A & N Islands  2001    Causes                   Love Affairs  Female
# 20  A & N Islands  2001    Causes  Other Causes (Please Specity)  Female
# 32  A & N Islands  2001    Causes        Other Prolonged Illness    Male
# 47  A & N Islands  2001    Causes         Failure in Examination    Male
#
#    Age_group  Total
# 13      0-14      1
# 20      0-14      1
# 32      0-14      1
# 47      0-14      1

# %%
plt.figure(figsize=(10,6))
plt.xticks(rotation=90)
sb.set_style('darkgrid')
sb.barplot(x='Type',y='Total',hue='Gender',data=cause_df,ci=False,palette='nipy_spectral_r')

# %% [markdown]
# Family Problems is the biggest factor for Suicide.
# Suicides because of Dowry disputes in Females is much larger as compared to Males whereas the factors like Bankrupt, Unemployment, Career issues and Drug abuse has badly effect Males, resulting in suicide.

# %% [markdown]
# ####  Due to Means adopted

# %%
means_df.head(4)
# Out:
#              State  Year      Type_code                       Type  Gender  \
# 277  A & N Islands  2001  Means_adopted                 By Hanging  Female
# 307  A & N Islands  2001  Means_adopted                 By Hanging    Male
# 312  A & N Islands  2001  Means_adopted    By Fire/Self Immolation  Female
# 315  A & N Islands  2001  Means_adopted  By Consuming Other Poison  Female
#
#     Age_group  Total
# 277      0-14      2
# 307      0-14      2
# 312     15-29      2
# 315     15-29      9

# %%
plt.figure(figsize=(10,6))
plt.xticks(rotation=90)
sb.set_style('whitegrid')
sb.barplot(x='Type',y='Total',hue='Gender',data=means_df,ci=False,palette='cool')

# %% [markdown]
# By hanging and By consuming insecticides are two most common factor by which suicides are committed.

# %% [markdown]
# #### Professional Profile

# %%
prof_df.head()
# Out:
#              State  Year             Type_code                     Type  \
# 443  A & N Islands  2001  Professional_Profile                  Student
# 448  A & N Islands  2001  Professional_Profile                  Student
# 456  A & N Islands  2001  Professional_Profile  Others (Please Specify)
# 461  A & N Islands  2001  Professional_Profile               House Wife
# 468  A & N Islands  2001  Professional_Profile  Others (Please Specify)
#
#      Gender Age_group  Total
# 443  Female      0-14      2
# 448    Male      0-14      1
# 456    Male      0-14      1
# 461  Female     15-29     21
# 468  Female     15-29      1

# %%
plt.figure(figsize=(10,6))
plt.xticks(rotation=90)
sb.set_style('whitegrid')
sb.barplot(x='Type',y='Total',hue='Gender',data=prof_df,ci=False,palette='winter')

# %% [markdown]
# Farming and other activities are the reasons that Males are more towards commiting suicides whereas Women as a house wife has a high rate of commiting suicides.

# %% [markdown]
# #### Education Status

# %%
edu_df.head()
# Out:
#              State  Year         Type_code                   Type  Gender  \
# 261  A & N Islands  2001  Education_Status           No Education  Female
# 263  A & N Islands  2001  Education_Status                 Middle  Female
# 266  A & N Islands  2001  Education_Status                Primary  Female
# 267  A & N Islands  2001  Education_Status  Matriculate/Secondary  Female
# 268  A & N Islands  2001  Education_Status  Matriculate/Secondary    Male
#
#     Age_group  Total
# 261    0-100+      4
# 263    0-100+     33
# 266    0-100+      7
# 267    0-100+      6
# 268    0-100+     10

# %%
plt.figure(figsize=(10,6))
plt.xticks(rotation=90)
sb.set_style('whitegrid')
sb.barplot(x='Type',y='Total',hue='Gender',data=edu_df,ci=False,palette='spring_r')

# %% [markdown]
# People that are less educated or having education less than Secondary has a high suicide rate.

# %% [markdown]
# #### Social Status

# %%
social_df.head()
# Out:
#               State  Year      Type_code           Type  Gender Age_group  \
# 552   A & N Islands  2001  Social_Status        Married  Female    0-100+
# 556   A & N Islands  2001  Social_Status  Never Married  Female    0-100+
# 559   A & N Islands  2001  Social_Status        Married    Male    0-100+
# 560   A & N Islands  2001  Social_Status  Never Married    Male    0-100+
# 1109  A & N Islands  2002  Social_Status  Never Married  Female    0-100+
#
#       Total
# 552      38
# 556      12
# 559      55
# 560      24
# 1109     17

# %%
plt.figure(figsize=(10,6))
plt.xticks(rotation=90)
sb.set_style('whitegrid')
sb.barplot(x='Type',y='Total',hue='Gender',data=social_df,ci=False,palette='autumn_r')

# %% [markdown]
# We can conclude that unsuccesful marriages is been the most common reason for attempting suicides.

# %% [markdown]
# # WordCloud

# %%
from wordcloud import WordCloud, ImageColorGenerator, STOPWORDS
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
try:
    words = " ".join(suicidal['Type'])
    def punctuation_stop(text):
        """remove punctuation and stop words"""
        filtered = []
        stop_words = set(stopwords.words('english'))
        word_tokens = word_tokenize(text)
        for w in word_tokens:
            if w not in stop_words and w.isalpha():
                filtered.append(w.lower())
        return filtered


    words_filtered = punctuation_stop(words)
    text = " ".join([ele for ele in words_filtered])
    wc= WordCloud(random_state=24,stopwords=STOPWORDS, max_words = 2000, width =1600, height = 800)
    wc.generate(text)

    plt.figure(figsize=(20,10), facecolor='k')
    plt.imshow(wc,interpolation="bilinear")
    plt.axis('off')
    plt.show()
except Exception as e:
    print(e)
    pass
